# %%
import requests
import pandas as pd
from pandas import json_normalize
import numpy as np
import json
import folium
from folium import plugins
from folium.plugins import HeatMap

# %%
# Foursquare Credentials
CLIENT_ID = "<HARD CODED CLIENT ID FOR API>"
CLIENT_SECRET = "<HARD CODED CLIENT SECRET FOR API>"
VERSION = "20210201"

# %% [markdown]
# # Pizza Places in Düsseldorf, North Rhine-Westphalia

# %%
# Set request parameters
request_params_pizza_dus = {
    "client_id": CLIENT_ID,
    "client_secret": CLIENT_SECRET,
    "v": VERSION,
    "categoryId": "4bf58dd8d48988d1ca941735",     # categoryId is for Pizza Places
    "near": "Düsseldorf",
    "radius": 4000,
    "limit": 100
}

# %%
url = 'https://api.foursquare.com/v2/venues/explore'

# GET request to receive data as set in request parameters
resp = requests.get(url=url, params=request_params_pizza_dus)
data = json.loads(resp.text)

# %%
venues = data["response"]["groups"][0]["items"]
d = json_normalize(venues)
d.head(3)
# Out:
#                        referralId  reasons.count  \
# 0  e-0-4b73209cf964a520f09c2de3-0              0
# 1  e-0-4b45c0fcf964a520e10f26e3-1              0
# 2  e-0-4d0a5cff5edd54815c3e059b-2              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
# 1  [{'summary': 'This spot is popular', 'type': '...
# 2  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id          venue.name venue.location.address  \
# 0  4b73209cf964a520f09c2de3       Pizzeria Lupo          Bolkerstr. 52
# 1  4b45c0fcf964a520e10f26e3             Da Gino      Kirchfeldstr. 135
# 2  4d0a5cff5edd54815c3e059b  Pizzeria Romantica   Düsselthaler Str. 48
#
#    venue.location.lat  venue.location.lng  \
# 0           51.226423            6.775604
# 1           51.212267            6.784068
# 2           51.233758            6.792516
#
#                        venue.location.labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 51.22642250101587...
# 1  [{'label': 'display', 'lat': 51.21226718188129...
# 2  [{'label': 'display', 'lat': 51.23375784654132...
#
#   venue.location.postalCode  ... venue.location.state venue.location.country  \
# 0                     40213  ...  Nordrhein-Westfalen            Deutschland
# 1                     40227  ...  Nordrhein-Westfalen            Deutschland
# 2                     40211  ...  Nordrhein-Westfalen            Deutschland
#
#                      venue.location.formattedAddress  \
# 0     [Bolkerstr. 52, 40213 Düsseldorf, Deutschland]
# 1  [Kirchfeldstr. 135 (Morsestr.), 40227 Düsseldo...
# 2  [Düsselthaler Str. 48, 40211 Düsseldorf, Deuts...
#
#                                     venue.categories venue.photos.count  \
# 0  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...                  0
# 1  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...                  0
# 2  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...                  0
#
#   venue.photos.groups  venue.location.crossStreet venue.location.neighborhood  \
# 0                  []                         NaN                         NaN
# 1                  []                   Morsestr.                         NaN
# 2                  []                         NaN                 Stadt-Mitte
#
#   venue.venuePage.id flags.outsideRadius
# 0                NaN                 NaN
# 1                NaN                 NaN
# 2                NaN                 NaN
#
# [3 rows x 22 columns]

# %%
# Choose relevant columns
df = d[["venue.name", "venue.location.address", "venue.location.lat", "venue.location.lng"]]

# Rename columns
pizza_places_dus = df.rename(columns={"venue.name": "Name", "venue.location.address": "Address", "venue.location.lat": "Latitude", "venue.location.lng": "Longitude"})

# Remove entries if data==NaN and reset index
pizza_places_dus.reset_index(drop=True)
pizza_places_dus.head()
# Out:
#                  Name               Address   Latitude  Longitude
# 0       Pizzeria Lupo         Bolkerstr. 52  51.226423   6.775604
# 1             Da Gino     Kirchfeldstr. 135  51.212267   6.784068
# 2  Pizzeria Romantica  Düsselthaler Str. 48  51.233758   6.792516
# 3      Pizzeria Pesto        Pionierstr. 54  51.214771   6.785539
# 4          Su Nuraghe        Am Wehrhahn 69  51.229043   6.793470

# %%
# Düsseldorf geolocation
lat = "51.221332448"
long = "6.785496858"

# Create Map instance für Düsseldorf
dus_map = folium.Map(location=[lat, long], zoom_start=13)
dus_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_eaff5c162cee49fb81c2219d75df8c13%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_eaff5c162cee49fb81c2219d75df8c13%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_eaff5c162cee49fb81c2219d75df8c13%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_eaff5c162cee49fb81c2219d75df8c13%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B51.221332448%2C%206.785496858%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# Function to add markers from df to df_map
def add_markers(df_map, df, color="red"):
    for lat, long, name in zip(df["Latitude"],
                          df["Longitude"],
                          df["Name"]):
        folium.CircleMarker(
            [lat, long],
            radius=2.5,
            fill=True,
            color=color,
            fill_color=color,
            fill_opacity=1
            ).add_to(df_map)

    display(df_map)

# %%
import selenium.webdriver
import time

# Function to save locally saved map (.html) as png-file
def save_map_png(filename_no_extension):
    driver = selenium.webdriver.PhantomJS()
    driver.set_window_size(1050, 850)
    driver.get("plt/"+filename_no_extension+".html")
    time.sleep(2)
    driver.save_screenshot("plt/"+filename_no_extension+".png")
    
    print("Success! File saved as png-file:", filename_no_extension+".png")

# %%
# Add pizza places to map
add_markers(dus_map, pizza_places_dus)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_eaff5c162cee49fb81c2219d75df8c13%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_eaff5c162cee49fb81c2219d75df8c13%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_eaff5c162cee49fb81c2219d75df8c13%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_eaff5c162cee49fb81c2219d75df8c13%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B51.221332448%2C%206.785496858%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# Add HeatMap
heatmap_data = pizza_places_dus[["Latitude", "Longitude"]].to_numpy().tolist()
dus_map.add_child(plugins.HeatMap(heatmap_data))

dus_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_eaff5c162cee49fb81c2219d75df8c13%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_eaff5c162cee49fb81c2219d75df8c13%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_eaff5c162cee49fb81c2219d75df8c13%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_eaff5c162cee49fb81c2219d75df8c13%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...

# %%
# Save map as .html and .png
dus_map.save("plt/Map_Duesseldorf_PizzaPlaces.html")
save_map_png("Map_Duesseldorf_PizzaPlaces")
# Out:
# C:\Users\User\anaconda3\lib\site-packages\selenium\webdriver\phantomjs\webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# Success! File saved as png-file: Map_Duesseldorf_PizzaPlaces.png

# %% [markdown]
# ## Colleges and Universities in Düsseldorf

# %%
# Set request parameters
request_params_college_dus = {
    "client_id": CLIENT_ID,
    "client_secret": CLIENT_SECRET,
    "v": VERSION,
    "categoryId": "4d4b7105d754a06372d81259",     # categoryId is for Colleges and University
    "near": "Düsseldorf",
    "radius": 4000,
    "limit": 100
}

# %%
url = 'https://api.foursquare.com/v2/venues/explore'

# GET request to receive data as set in request parameters
resp = requests.get(url=url, params=request_params_college_dus)
data = json.loads(resp.text)

# %%
venues = data["response"]["groups"][0]["items"]
d = json_normalize(venues)
d.head(3)
# Out:
#                        referralId  reasons.count  \
# 0  e-0-4e671d91e4cdfdecb0287eae-0              0
# 1  e-0-4bae0355f964a520e37a3be3-1              0
# 2  e-0-4c9e6c15d3c2b60c243acbbc-2              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
# 1  [{'summary': 'This spot is popular', 'type': '...
# 2  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id                                venue.name  \
# 0  4e671d91e4cdfdecb0287eae     Walter-Eucken-Berufskolleg Dependance
# 1  4bae0355f964a520e37a3be3                        Konfuzius Institut
# 2  4c9e6c15d3c2b60c243acbbc  Die Brücke am Heinrich-Heine-Platz (VHS)
#
#    venue.location.lat  venue.location.lng  \
# 0           51.231055            6.791989
# 1           51.219497            6.786359
# 2           51.224711            6.774901
#
#                        venue.location.labeledLatLngs venue.location.cc  \
# 0  [{'label': 'display', 'lat': 51.23105490466366...                DE
# 1  [{'label': 'display', 'lat': 51.219497, 'lng':...                DE
# 2  [{'label': 'display', 'lat': 51.224711, 'lng':...                DE
#
#   venue.location.city  ...                    venue.location.formattedAddress  \
# 0          Düsseldorf  ...                          [Düsseldorf, Deutschland]
# 1          Düsseldorf  ...    [Graf-Adolf Straße 63, Düsseldorf, Deutschland]
# 2          Düsseldorf  ...  [Kasernenstraße 6 (At Wallstraße), 40213 Düsse...
#
#                                     venue.categories venue.photos.count  \
# 0  [{'id': '4d4b7105d754a06372d81259', 'name': 'C...                  0
# 1  [{'id': '4bf58dd8d48988d198941735', 'name': 'C...                  0
# 2  [{'id': '4bf58dd8d48988d1a0941735', 'name': 'C...                  0
#
#   venue.photos.groups  venue.location.address venue.location.crossStreet  \
# 0                  []                     NaN                        NaN
# 1                  []    Graf-Adolf Straße 63                        NaN
# 2                  []        Kasernenstraße 6              At Wallstraße
#
#   venue.location.postalCode venue.location.neighborhood venue.venuePage.id  \
# 0                       NaN                         NaN                NaN
# 1                       NaN                         NaN                NaN
# 2                     40213                         NaN                NaN
#
#   flags.outsideRadius
# 0                 NaN
# 1                 NaN
# 2                 NaN
#
# [3 rows x 22 columns]

# %%
# Choose relevant columns
df = d[["venue.name", "venue.location.address", "venue.location.lat", "venue.location.lng"]]

# Rename columns
colleges_dus = df.rename(columns={"venue.name": "Name", "venue.location.address": "Address", "venue.location.lat": "Latitude", "venue.location.lng": "Longitude"})

# Remove entries if data==NaN and reset index
colleges_dus.reset_index(drop=True)
colleges_dus.head()
# Out:
#                                             Name                     Address  \
# 0          Walter-Eucken-Berufskolleg Dependance                         NaN
# 1                             Konfuzius Institut        Graf-Adolf Straße 63
# 2       Die Brücke am Heinrich-Heine-Platz (VHS)            Kasernenstraße 6
# 3                   Zentralbibliothek Düsseldorf  Bertha-von-Suttner-Platz 1
# 4  DAPR - Deutsche Akademie für Public Relations                         NaN
#
#     Latitude  Longitude
# 0  51.231055   6.791989
# 1  51.219497   6.786359
# 2  51.224711   6.774901
# 3  51.218803   6.796055
# 4  51.229192   6.772290

# %%
add_markers(dus_map, colleges_dus, "black")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_eaff5c162cee49fb81c2219d75df8c13%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_eaff5c162cee49fb81c2219d75df8c13%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_eaff5c162cee49fb81c2219d75df8c13%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_eaff5c162cee49fb81c2219d75df8c13%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...

# %%
# Save map as .html and .png
dus_map.save("plt/Map_Duesseldorf_PizzaPlaces_Colleges.html")
save_map_png("Map_Duesseldorf_PizzaPlaces_Colleges")
# Out:
# C:\Users\User\anaconda3\lib\site-packages\selenium\webdriver\phantomjs\webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# Success! File saved as png-file: Map_Duesseldorf_PizzaPlaces_Colleges.png

# %% [markdown]
# # Pizza Places in Essen, North Rhine-Westphalia

# %%
# GET request to receive data as set in request parameters
request_params = {
    "client_id": CLIENT_ID,
    "client_secret": CLIENT_SECRET,
    "v": VERSION,
    "categoryId": "4bf58dd8d48988d1ca941735",        # categoryId is for Pizza Places
    "near": "Essen",
    "radius": 4000,
    "limit": 100
}

url = 'https://api.foursquare.com/v2/venues/explore'

# GET request to receive data as set in request parameters
resp = requests.get(url=url, params=request_params)
data = json.loads(resp.text)

# %%
venues = data["response"]["groups"][0]["items"]
d = json_normalize(venues)
d.head(3)
# Out:
#                        referralId  reasons.count  \
# 0  e-0-4b76e544f964a52024682ee3-0              0
# 1  e-0-4c330dc87cc0c9b67820f19a-1              0
# 2  e-0-4ccdacb6c0378cfab9f88e48-2              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
# 1  [{'summary': 'This spot is popular', 'type': '...
# 2  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id venue.name  venue.location.address  \
# 0  4b76e544f964a52024682ee3     Zodiac        Witteringstr. 41
# 1  4c330dc87cc0c9b67820f19a    Venezia  Rüttenscheider Str. 52
# 2  4ccdacb6c0378cfab9f88e48  Il Mulino          Rathenaustr. 2
#
#    venue.location.lat  venue.location.lng  \
# 0           51.441444            7.010918
# 1           51.439392            7.006064
# 2           51.453595            7.011556
#
#                        venue.location.labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 51.44144354435105...
# 1  [{'label': 'display', 'lat': 51.43939178552952...
# 2  [{'label': 'display', 'lat': 51.45359494950699...
#
#   venue.location.postalCode  ... venue.location.city venue.location.state  \
# 0                     45130  ...               Essen  Nordrhein-Westfalen
# 1                     45130  ...               Essen  Nordrhein-Westfalen
# 2                     45127  ...               Essen  Nordrhein-Westfalen
#
#   venue.location.country                    venue.location.formattedAddress  \
# 0            Deutschland       [Witteringstr. 41, 45130 Essen, Deutschland]
# 1            Deutschland  [Rüttenscheider Str. 52, 45130 Essen, Deutschl...
# 2            Deutschland         [Rathenaustr. 2, 45127 Essen, Deutschland]
#
#                                     venue.categories venue.photos.count  \
# 0  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...                  0
# 1  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...                  0
# 2  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...                  0
#
#    venue.photos.groups venue.location.crossStreet flags.outsideRadius  \
# 0                   []                        NaN                 NaN
# 1                   []                        NaN                 NaN
# 2                   []                        NaN                 NaN
#
#   venue.venuePage.id
# 0                NaN
# 1                NaN
# 2                NaN
#
# [3 rows x 21 columns]

# %%
# Choose relevant columns
df = d[["venue.name", "venue.location.address", "venue.location.lat", "venue.location.lng"]]

# Rename columns
pizza_places_essen = df.rename(columns={"venue.name": "Name", "venue.location.address": "Address", "venue.location.lat": "Latitude", "venue.location.lng": "Longitude"})

# Remove entries if data==NaN and reset index
pizza_places_essen.reset_index(drop=True)
pizza_places_essen.head()
# Out:
#                Name                 Address   Latitude  Longitude
# 0            Zodiac        Witteringstr. 41  51.441444   7.010918
# 1           Venezia  Rüttenscheider Str. 52  51.439392   7.006064
# 2         Il Mulino          Rathenaustr. 2  51.453595   7.011556
# 3  Cantina Italiana         Paulinenstr. 22  51.437926   7.012619
# 4         Cafe Nord        Viehofer Platz 1  51.461856   7.013737

# %%
# Essen geolocation
lat, long = "51.450832", "7.013056"

# Create Map instance for Essen
essen_map = folium.Map(location=[lat, long], zoom_start=13)

# %%
# Add markers to spot Pizza Places in Essen
add_markers(essen_map, pizza_places_essen)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_677e8249bc2a49279c1e37ca52e10dfe%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_677e8249bc2a49279c1e37ca52e10dfe%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_677e8249bc2a49279c1e37ca52e10dfe%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_677e8249bc2a49279c1e37ca52e10dfe%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B51.450832%2C%207.013056%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# Add HeatMap
heatmap_data_essen = pizza_places_essen[["Latitude", "Longitude"]].to_numpy().tolist()
essen_map.add_child(plugins.HeatMap(heatmap_data_essen))

essen_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_677e8249bc2a49279c1e37ca52e10dfe%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_677e8249bc2a49279c1e37ca52e10dfe%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_677e8249bc2a49279c1e37ca52e10dfe%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_677e8249bc2a49279c1e37ca52e10dfe%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...

# %%
# Save map as .html and .png
essen_map.save("plt/Map_Essen_PizzaPlaces.html")
save_map_png("Map_Essen_PizzaPlaces")
# Out:
# C:\Users\User\anaconda3\lib\site-packages\selenium\webdriver\phantomjs\webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# Success! File saved as png-file: Map_Essen_PizzaPlaces.png

# %% [markdown]
# ## Colleges and Universities in Essen

# %%
request_params_college_essen = {
    "client_id": CLIENT_ID,
    "client_secret": CLIENT_SECRET,
    "v": VERSION,
    "categoryId": "4d4b7105d754a06372d81259",     # categoryId is for Colleges and University
    "near": "Essen",
    "radius": 4000,
    "limit": 100
}

url = 'https://api.foursquare.com/v2/venues/explore'
resp = requests.get(url=url, params=request_params_college_essen)
data = json.loads(resp.text)

# %%
venues = data["response"]["groups"][0]["items"]
d = json_normalize(venues)
d.head(3)
# Out:
#                        referralId  reasons.count  \
# 0  e-0-4dd644bad4c05d5096cb9a7c-0              0
# 1  e-0-4bc3fb93b492d13afb8da960-1              0
# 2  e-0-4cc17b9f53f6b71313077df8-2              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
# 1  [{'summary': 'This spot is popular', 'type': '...
# 2  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id  \
# 0  4dd644bad4c05d5096cb9a7c
# 1  4bc3fb93b492d13afb8da960
# 2  4cc17b9f53f6b71313077df8
#
#                                           venue.name venue.location.address  \
# 0                                 Weststadt Akademie   Thea-Leymann-Str. 35
# 1  Campus Essen, Schützenbahn – Universität Duisb...        Schützenbahn 70
# 2                                  VWA Essen (SHZ 1)      Herkulesstraße 32
#
#    venue.location.lat  venue.location.lng  \
# 0           51.457561            7.001901
# 1           51.461522            7.016845
# 2           51.456703            7.022815
#
#                        venue.location.labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 51.4575614166877,...
# 1  [{'label': 'display', 'lat': 51.46152226588673...
# 2  [{'label': 'display', 'lat': 51.45670257735735...
#
#   venue.location.postalCode  ... venue.location.city venue.location.state  \
# 0                     45127  ...               Essen  Nordrhein-Westfalen
# 1                     45117  ...               Essen  Nordrhein-Westfalen
# 2                     45127  ...               Essen  Nordrhein-Westfalen
#
#   venue.location.country                   venue.location.formattedAddress  \
# 0            Deutschland  [Thea-Leymann-Str. 35, 45127 Essen, Deutschland]
# 1            Deutschland       [Schützenbahn 70, 45117 Essen, Deutschland]
# 2            Deutschland     [Herkulesstraße 32, 45127 Essen, Deutschland]
#
#                                     venue.categories venue.photos.count  \
# 0  [{'id': '4d4b7105d754a06372d81259', 'name': 'C...                  0
# 1  [{'id': '4bf58dd8d48988d1ae941735', 'name': 'U...                  0
# 2  [{'id': '4bf58dd8d48988d1ae941735', 'name': 'U...                  0
#
#    venue.photos.groups venue.location.neighborhood venue.venuePage.id  \
# 0                   []                         NaN                NaN
# 1                   []                         NaN                NaN
# 2                   []                         NaN                NaN
#
#   flags.outsideRadius
# 0                 NaN
# 1                 NaN
# 2                 NaN
#
# [3 rows x 21 columns]

# %%
# Choose relevant columns
df = d[["venue.name", "venue.location.address", "venue.location.lat", "venue.location.lng"]]

# Rename columns
colleges_essen = df.rename(columns={"venue.name": "Name", "venue.location.address": "Address", "venue.location.lat": "Latitude", "venue.location.lng": "Longitude"})

# Remove entries if data==NaN and reset index
colleges_essen.reset_index(drop=True)
colleges_essen.head()
# Out:
#                                                 Name               Address  \
# 0                                 Weststadt Akademie  Thea-Leymann-Str. 35
# 1  Campus Essen, Schützenbahn – Universität Duisb...       Schützenbahn 70
# 2                                  VWA Essen (SHZ 1)     Herkulesstraße 32
# 3          Universität Duisburg-Essen - Campus Essen    Universitätsstr. 2
# 4                             Universität Bibliothek                   NaN
#
#     Latitude  Longitude
# 0  51.457561   7.001901
# 1  51.461522   7.016845
# 2  51.456703   7.022815
# 3  51.463902   7.007517
# 4  51.464549   7.007665

# %%
add_markers(essen_map, colleges_essen, "black")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_677e8249bc2a49279c1e37ca52e10dfe%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_677e8249bc2a49279c1e37ca52e10dfe%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_677e8249bc2a49279c1e37ca52e10dfe%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_677e8249bc2a49279c1e37ca52e10dfe%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...

# %%
# Save map as .html and .png
essen_map.save("plt/Map_Essen_PizzaPlaces_Colleges.html")
save_map_png("Map_Essen_PizzaPlaces_Colleges")
# Out:
# C:\Users\User\anaconda3\lib\site-packages\selenium\webdriver\phantomjs\webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# Success! File saved as png-file: Map_Essen_PizzaPlaces_Colleges.png
